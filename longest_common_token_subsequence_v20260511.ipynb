# %% [markdown]
# # Longest Common Token Subsequence: Update 2026-05-11
#
# This algorithm is developed and designed to compare two text sequences, especially of person, company, or region names or addresses: e.g. 'Alan Turing' vs. 'Alan Mathison Turing', 'United States of America' vs. 'U.S.A.', etc.
#
# The code is based on the Longest Common Subsequence algorithm, where the order of characters/tokens/words matters and therefore a lower matching score is potentially calculated for some cases: e.g. 'Albert Einstein' vs. 'Einstein, Albert'. To overcome this challenge, the code locally performs the Longest Common Subsequence algorithm on every possible pair of tokens, whose time complexity still remains O(mn), where m = len(text1) and n = len(text2).
#
# And then, an algorithm for finding the maximum sum of values from non-overlapping rectangles is used to find the best matching result. First, I assume that a token pair represents a rectangle; that a rectangle represents a node in a graph; and that overlapping rectangles either on x-axis or y-axis are all directly connected adjacent nodes. This leads to a group or groups of graph, where each node has a value equivalent to the number of matched characters in a token pair. Now the problem is to find the best subset of nodes, using a brute force approach, that have the maximum sum of the node values, under the restriction that no two adjacent node values are used. This is a well-known house robbery problem but on a complex graph, rather than on a 1-d line or a tree. Unlike a house robbery problem on a 1-d line or a tree, which we can make the most out of dynamic programming and achieve O(n) time complexity, graphs that contain circles seems to break a kind of simplicity and prevent the use of dynamic programming, possibly leading to O(2^n) time complexity. To efficiently explore the nodes in the graph, I made the use of the depth-first-search approach.
#
# Overall, this algorithm is not ideal for long text comparison, because of potential O(2^n) time complexity due to the brute-force approach used. However, it is fast and useful for small text comparison, like entity names or addresses.
#
# Please see the test result below on some examples.
#
# Bomsoo Kim

# %% [markdown]
# ## Utils

# %%
import threading
import time

class TimeLimitExceededException(Exception):
    def __init__(self, error_message=''):
        super().__init__(error_message)

def use_threading_stop_event(func):# decorator
    def inner(*args, **kwargs):
        if ('time_limit_sec' in kwargs) and kwargs['time_limit_sec'] is not None:
            time_limit_sec = kwargs['time_limit_sec']
            stop_event = threading.Event()

            kwargs['threading_stop_event'] = stop_event # 'threading_stop_event' keyword argument must be defined in 'func'
            kwargs['threading_outputs'] = [None] # 'threading_outputs' keyword argument must be defined in 'func'

            my_thread = threading.Thread(target=func, args=args, kwargs=kwargs)

            my_thread.start()
            
            check_time_interval_sec = 0.000001
            tic = time.time()
            while True:
                if not my_thread.is_alive(): # if thread is completed, we don't need to wait
                    break
                elif (time.time() - tic) > time_limit_sec: # if time limit is exceeded, schedule a stop event
                    stop_event.set() # Signal stop

                time.sleep(check_time_interval_sec)

                if check_time_interval_sec < 1: # 1 sec
                    check_time_interval_sec += check_time_interval_sec # exponentially grow
                    check_time_interval_sec = min(1, check_time_interval_sec) # 1 sec

            my_thread.join()

            return kwargs['threading_outputs'][0]
        else:
            return func(*args, **kwargs)

    return inner

# %%
def flatten_trie_node(node, arr, matches):
    if not node:
        matches.append(list(arr))
        return
    
    for k in node.keys():
        arr.append(k)
        flatten_trie_node(node[k], arr, matches)
        arr.pop()
    return

# %% [markdown]
# ## Levenshtein Distance
# - [72. Edit Distance](https://leetcode.com/problems/edit-distance/)

# %%
def edit_distance(word1, word2): # https://leetcode.com/problems/edit-distance/
    """
    :type word1: str
    :type word2: str
    :rtype: int
    """
    dp = [[0]*(len(word2)+1) for _ in range(len(word1)+1)]
    
    for j in range(len(word2)-1, -1, -1):
        dp[-1][j] += 1 + dp[-1][j+1] # initial value
    
    for i in range(len(word1)-1, -1, -1):
        dp[i][-1] += 1 + dp[i+1][-1] # initial value
        
        for j in range(len(word2)-1, -1, -1):
            if word1[i] == word2[j]:
                dp[i][j] = dp[i+1][j+1]
            else:
                dp[i][j] = 1 + min(dp[i+1][j], dp[i][j+1], dp[i+1][j+1])
    return dp[0][0]

# if __name__=='__main__':
#     word1 = "horse"; word2 = "ros"
#     print(edit_distance(word1, word2))
#     # Output: 3
#     # Explanation: 
#     # horse -> rorse (replace 'h' with 'r')
#     # rorse -> rose (remove 'r')
#     # rose -> ros (remove 'e')
#     # Example 2:

#     word1 = "intention"; word2 = "execution"
#     print(edit_distance(word1, word2))
#     # Output: 5
#     # Explanation: 
#     # intention -> inention (remove 't')
#     # inention -> enention (replace 'i' with 'e')
#     # enention -> exention (replace 'n' with 'x')
#     # exention -> exection (replace 'n' with 'c')
#     # exection -> execution (insert 'u')

# %% [markdown]
# ## Longest common subsequence
# - [1143. Longest Common Subsequence](https://leetcode.com/problems/longest-common-subsequence/description/)

# %%
def longest_common_subsequence(text1, text2): # https://leetcode.com/problems/longest-common-subsequence/
    if True:
        """
        :type text1: str
        :type text2: str
        :rtype: int
        """
        ### Update 03/02/2025: added matched sequence detection part
        ### Update 07/26/2022: all solutions are reviewed
        ### ref) 1143. Longest Common Subsequence: https://leetcode.com/problems/longest-common-subsequence/
        
        ### dynamic programming (bottom-up) with space optimizatoin ##################
        if len(text1) < len(text2): # to make sure text2 is always shorter than text1
            text1, text2 = text2, text1

        prev = [0]*(len(text2)+1) # space complexity: O(min(len(text1), len(text2)))
        curr = [0]*(len(text2)+1) # space complexity: O(min(len(text1), len(text2)))
        for i in range(len(text1)-1, -1, -1): # time complexity: O(len(text1) * len(text2))
            for j in range(len(text2)-1, -1, -1):
                if text1[i] == text2[j]:
                    curr[j] = 1 + prev[j+1]
                else:
                    curr[j] = max(prev[j], curr[j+1])
            prev, curr = curr, prev

        return prev[0]

        # ### dynamic programming (bottom-up) with matched sequence detection (03/02/2025) ###################
        # dp = [[0]*(len(text2)+1) for _ in range(len(text1)+1)] # space complexity: O(len(text1) * len(text2))

        # for i in range(len(text1)-1, -1, -1): # time complexity: O(len(text1) * len(text2))
        #     for j in range(len(text2)-1, -1, -1):
        #         if text1[i] == text2[j]:
        #             dp[i][j] = 1 + dp[i+1][j+1]
        #         else:
        #             dp[i][j] = max(dp[i+1][j], dp[i][j+1])

        # #--- detect one of all possible matched sequences (03/02/2025) ---
        # matches = []
        # target = dp[0][0]
        # j_start = 0
        # for i in range(len(text1)):
        #     for j in range(j_start, len(text2)):
        #         if (text1[i] == text2[j]) and (target == dp[i][j]):
        #             matches.append([i, j])
        #             j_start = j + 1 # no need to see indexes less than matched j, because of the sequence order
        #             target -= 1 # update the next target value
        #             break # no need to see indexes great than matched j, because the matched is found!
        #     if target == 0:
        #         break
        # assert dp[0][0] == len(matches), 'LCS value does not match the number of detected characters...'

        # # return dp[0][0]
        # return dp[0][0], matches

        ### dynamic programming (bottom-up) ###################
        # dp = [[0]*(len(text2)+1) for _ in range(len(text1)+1)] # space complexity: O(len(text1) * len(text2))

        # for i in range(len(text1)-1, -1, -1): # time complexity: O(len(text1) * len(text2))
        #     for j in range(len(text2)-1, -1, -1):
        #         if text1[i] == text2[j]:
        #             dp[i][j] = 1 + dp[i+1][j+1]
        #         else:
        #             dp[i][j] = max(dp[i+1][j], dp[i][j+1])

        # return dp[0][0]
                
        ### dynamix programming (top-down) ####################
    #     self.text1, self.text2 = text1, text2
    #     self.dp = {}
        
    #     return self.find_max_sub(0,0)
        
    # def find_max_sub(self, i, j):
    #     if (i,j) in self.dp:
    #         return self.dp[(i,j)]
        
    #     if i >= len(self.text1) or j >= len(self.text2):
    #         return 0
        
    #     if self.text1[i]==self.text2[j]:
    #         self.dp[(i,j)] = 1 + self.find_max_sub(i+1, j+1)
    #     else:
    #         self.dp[(i,j)] = max(self.find_max_sub(i, j+1), self.find_max_sub(i+1, j))
        
    #     return self.dp[(i,j)]

        ### Brad: solution with Longest Increasing Subsequence (Time Limt Exceeded) #########
        # arr = []
        # for i in range(len(text1)):
        #     for j in range(len(text2)-1, -1, -1):
        #         if text1[i] == text2[j]:
        #             arr.append(j)
                    
        # con = []
        # for j in arr: # Longest Increasing Subsequence
        #     if len(con) == 0 or con[-1] < j:
        #         con.append(j)
        #     else:
        #         for k in range(len(con)):
        #             if j <= con[k]:
        #                 con[k] = j
        #                 break
                        
        # return len(con)

# if __name__=='__main__':
#     text1 = "abcde"; text2 = "ace"
#     print(longest_common_subsequence(text1, text2)) # The longest common subsequence is "ace" and its length is 3

#     text1 = "abc"; text2 = "abc"
#     print(longest_common_subsequence(text1, text2)) # The longest common subsequence is "abc" and its length is 3

#     text1 = "abc"; text2 = "def"
#     print(longest_common_subsequence(text1, text2)) # There is no such common subsequence, so the result is 0

# %% [markdown]
# ## Longest common subsequence, with all possible solutions

# %%
def lcs(i, j, text1, text2, dp=None, get_trie=True): # tested 2025-04-25
    if (i,j) in dp:
        return dp[(i,j)]
   
    if i >= len(text1) or j >= len(text2):
        return 0, {}
    
    if text1[i] == text2[j]:       
        out_ = lcs(i+1, j+1, text1, text2, dp=dp, get_trie=get_trie)
        out0 = 1 + out_[0], {(i,j):out_[1]}
    else:
        out0 = -1, {}
    out1 = lcs(i, j+1, text1, text2, dp=dp, get_trie=get_trie)
    out2 = lcs(i+1, j, text1, text2, dp=dp, get_trie=get_trie)
    
    max_val = max(out0[0], out1[0], out2[0])
    trie = {}
    if get_trie:
        if out0[0] == max_val:
            trie.update(out0[1])
        if out1[0] == max_val:
            trie.update(out1[1])
        if out2[0] == max_val:
            trie.update(out2[1])
    
    dp[(i,j)] = max_val, trie
    return dp[(i,j)]

# %% [markdown]
# ## Maximum value of non-overlapping intervals, with all possible solutions
# - [1235. Maximum Profit in Job Scheduling](https://leetcode.com/problems/maximum-profit-in-job-scheduling/description/)
# - [2008. Maximum Earnings From Taxi](https://leetcode.com/problems/maximum-earnings-from-taxi/description/)
# - [1751. Maximum Number of Events That Can Be Attended II](https://leetcode.com/problems/maximum-number-of-events-that-can-be-attended-ii/description/)

# %%
# def get_all_non_overlapping_intervals(i, intervals, START=0, END=1, VALUE=2, dp=None, get_trie=True): # tested 2025-04-25
#     if i in dp:
#         return dp[i]

#     if i >= len(intervals):
#         return 0, {}
    
#     #--- binary search --------------------------
#     x, y = i, len(intervals)
#     while x + 1 < y:
#         m = (x + y) // 2
#         if intervals[i][END] < intervals[m][START]: # <, when [1,2] and [3,4] is considered non-overlapping
#         # if intervals[i][END] <= intervals[m][START]: # <=, when [1,2] and [2,3] is considered non-overlapping
#             y = m
#         else:
#             x = m

#     out_ = get_all_non_overlapping_intervals(x + 1, intervals, START=START, END=END, VALUE=VALUE, dp=dp, get_trie=get_trie)
#     out1 = intervals[i][VALUE] + out_[0], {i: out_[1]}
#     out2 = get_all_non_overlapping_intervals(i + 1, intervals, START=START, END=END, VALUE=VALUE, dp=dp, get_trie=get_trie)

#     max_val = max(out1[0], out2[0])
#     trie = {}
#     if get_trie:
#         if out1[0] == max_val:
#             trie.update(out1[1])
#         if out2[0] == max_val:
#             trie.update(out2[1])

#     dp[i] = max_val, trie
#     return dp[i]

# # if __name__=='__main__':
# #     # intervals = [[4,6,3],[2,5,7]]
# #     intervals = sorted([[1,3,3],[4,6,3],[2,5,6]])

# #     max_val, trie = get_all_non_overlapping_intervals(0, intervals, dp={})

# #     matches = []
# #     flatten_trie_node(trie, [], matches)
# #     print(matches)

# %% [markdown]
# ## Union Find (Disjoint Sets)
# - [1971. Find if Path Exists in Graph](https://leetcode.com/problems/find-if-path-exists-in-graph/)

# %%
class Union_Find:
    def __init__(self, num_points, edges):
        """
        
        """
        self.roots = [i for i in range(num_points)]
        self.ranks = [1 for _ in range(num_points)]

        for i, j in edges:
            self.union(i, j)
        return

    def find_root(self, i):
        if self.roots[i] != i:
            self.roots[i] =  self.find_root(self.roots[i])
        return self.roots[i]

    def union(self, i, j):
        x = self.find_root(i)
        y = self.find_root(j)
        if x != y:
            if self.ranks[x] > self.ranks[y]:
                self.roots[y] = x
            elif self.ranks[x] < self.ranks[y]:
                self.roots[x] = y
            else:
                self.roots[x] = y
                self.ranks[y] += self.ranks[x]
        return

# if __name__=='__main__':
#     values = [1,2,6,3,     1,3,4]
#     edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [4,5],[5,6]]
#     #---------------------------------------------------------
#     # values = [1,2,3]
#     # edges = []
#     #---------------------------------------------------------

#     num_points = len(values)

#     #--- find disjoint sets -------------------------
#     djs = Union_Find(num_points, edges) # disjoin sets

#     i_roots = set()
#     for i in range(num_points):
#         r = djs.find_root(i) # to make sure there is only one root for each group
#         i_roots.add(r)
#     print(f'i_roots = {i_roots}')

# %% [markdown]
# ## House robbery
# - [1192. Critical Connections in a Network](https://leetcode.com/problems/critical-connections-in-a-network)
# - [337. House Robber III](https://leetcode.com/problems/house-robber-iii/)

# %%
# def find_critical_connections_in_network(prev, i, graph={}, ranks={}, critial_connections=[]): # UPDATE: 2026-03-16
#     ranks[i] = len(ranks)

#     min_rank = ranks[i]
#     if i in graph:
#         for j in graph[i]:
#             if j == prev:
#                 continue
#             elif j in ranks:
#                 rank_j = ranks[j]
#             else:
#                 rank_j = find_critical_connections_in_network(i, j, graph=graph, ranks=ranks, critial_connections=critial_connections)

#                 if ranks[i] < rank_j:
#                     critial_connections.append([i,j])

#             min_rank = min(min_rank, rank_j)

#     return min_rank

# if __name__=='__main__':
#     edges = []
#     #--- 1-d problem ----------------------
#     # edges = [[i,i+1] for i in range(8)]
#     #---- complete connection -------------
#     # edges = [[i,j] for i in range(15) for j in range(i+1, 15)]
#     #--- diamond and line -----------------------------------
#     # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [4,5],[5,6]]
#     # #---diamond with line -----------------------------------
#     # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [2,4],[4,5]]
#     #--------------------------------------

#     graph = {}
#     for i,j in edges:
#         graph.setdefault(i, []).append(j)
#         graph.setdefault(j, []).append(i)
#     # print(f'graph = {graph}')

#     critial_connections = []
#     _ = find_critical_connections_in_network(-1, 0, graph=graph, ranks={}, critial_connections=critial_connections)
#     print(f'critial_connections = {critial_connections}')

# %%
# def dfs(i, prev=-1, max_visit=-1, visits={}, graph={}):
#     if i not in visits:
#         visits[i] = len(visits)

#     max_visit = max(max_visit, visits[i])

#     for j in graph[i]:
#         if j == prev: # if j is the previouis 
#             continue
#         elif (j not in visits) or (visits[j] == max_visit + 1): # explore unvisited nodes or visit nodes in the same order
#             print(f'{i} --> {j} [OK]')
#             out = dfs(j, prev=i, max_visit=max_visit, visits=visits, graph=graph)
#             max_visit = max(max_visit, out['max_visit'])
#         elif visits[i] > visits[j]: # previously visits node: low rank contact
#             print(f'{i} --> {j} [Low rank contact]')
#             pass
#         elif visits[i] < visits[j]: # previously visits node: high rank contact
#             print(f'{i} --> {j} [High rank contact]')
#             pass
#         else:
#             raise(Exception('Brad error: impossible case, unless a self loop is allowed...'))

#     return {'max_visit':max_visit}

# %%
# def dfs_2(i, prev=-1, max_visit=-1, visits={}, graph={}, robbed=[], values=[], threading_stop_event=None):
#     if (threading_stop_event is not None) and threading_stop_event.is_set():
#         raise(TimeLimitExceededException(f'Brad error: time limit exceeded...')) 

#     if i not in visits:
#         visits[i] = len(visits)

#     # max_visit_0 = max_visit
#     max_visit_0 = max(max_visit, visits[i])

#     if any(robbed[j] > 0 for j in graph[i] if robbed[j] is not None): # check if there is any neighborhood robbed, among visited
#         modes = ['not rob'] # if any, then decide not to rob the current node
#     else:
#         modes = ['not rob', 'rob'] # if there is no neighborhood robbed, then there are two options: do not rob, or rob

#     max_val = 0
#     for mode in modes:
#         robbed[i] = 1 if mode == 'rob' else 0
#         # max_visit = max(max_visit_0, visits[i])
#         max_visit = max_visit_0 # initialize
#         sum_val = values[i] if mode == 'rob' else 0 # initialize

#         for j in graph[i]:
#             if j == prev: # if j is the previouis 
#                 continue
#             elif (j not in visits) or (visits[j] == max_visit + 1): # explore unvisited nodes or visit nodes in the same order
#                 # print(f'{i} --> {j} [OK]')
#                 out = dfs_2(j, prev=i, max_visit=max_visit, visits=visits, graph=graph, robbed=robbed, values=values, threading_stop_event=threading_stop_event)
#                 max_visit = max(max_visit, out['max_visit'])
#                 sum_val += out['max_val']
#             elif visits[i] > visits[j]: # previously visits node: low rank contact
#                 # print(f'{i} --> {j} [Low rank contact]')
#                 pass
#             elif visits[i] < visits[j]: # previously visits node: high rank contact
#                 # print(f'{i} --> {j} [High rank contact]')
#                 pass
#             else:
#                 raise(Exception('Brad error: impossible case, unless a self loop is allowed...'))

#         max_val = max(max_val, sum_val)
#     robbed[i] = None
#     return {'max_visit':max_visit, 'max_val':max_val}

# # if __name__=='__main__':
# #     values = [0,1,2,3,4,5,6]
# #     edges = [
# #         [0,1],[1,2],[2,3],[3,1],[3,0],[0,4],[4,5],[4,6],[0,6],
# #     ]

# #     values = [5, 2, 1, 1, 2, 12, 2, 2, 2, 1, 1, 1, 1, 2, 2, 7, 2, 2, 2, 1, 1, 1, 1, 1, 3]
# #     edges = [[0, 1], [0, 2], [0, 3], [0, 4], [0, 13], [0, 14], [1, 2], [1, 3], [1, 5], [1, 15], [1, 22], [2, 3], [2, 24], [3, 24], [4, 5], [4, 7], [4, 8], [4, 10], [4, 11], [4, 12], [4, 13], [4, 14], [5, 6], [5, 7], [5, 8], [5, 9], [5, 10], [5, 11], [5, 12], [5, 15], [5, 22], [5, 23], [6, 7], [6, 8], [6, 16], [6, 17], [6, 18], [7, 8], [7, 9], [7, 10], [7, 11], [7, 12], [7, 16], [7, 17], [7, 18], [8, 10], [8, 11], [8, 12], [8, 16], [8, 17], [8, 18], [9, 10], [9, 19], [9, 24], [10, 19], [10, 24], [11, 12], [11, 20], [11, 24], [12, 21], [12, 24], [13, 14], [13, 15], [13, 17], [13, 18], [13, 19], [13, 20], [13, 21], [14, 15], [14, 18], [14, 19], [14, 20], [14, 21], [15, 16], [15, 17], [15, 18], [15, 19], [15, 20], [15, 21], [15, 22], [15, 23], [16, 17], [16, 18], [17, 18], [18, 19], [18, 20], [18, 21], [19, 24], [20, 21], [20, 24], [21, 24], [22, 23], [22, 24], [23, 24]]

# #     graph = {}
# #     for i,j in edges:
# #         graph.setdefault(i, []).append(j)
# #         graph.setdefault(j, []).append(i)
# #     print(f'graph = {graph}')

# #     # visits={}
# #     # out = dfs(0, prev=-1, max_visit=-1, visits=visits, graph=graph)
# #     # print(out)
# #     # # dfs(1, prev=-1, max_visit=-1, visits=visits, graph=graph)

# #     print(f'values = {values}')
# #     robbed = [None]*len(values)
# #     print(f'robbed = {robbed}')
# #     for i in range(1):
# #         out2 = dfs_2(i, prev=-1, max_visit=-1, visits={}, graph=graph, robbed=robbed, values=values)
# #         print(out2)

# %%
def dfs_3(i, prev=-1, max_visit=-1, visits={}, graph={}, robbed=[], values=[], get_matches=False, threading_stop_event=None):
    if (threading_stop_event is not None) and threading_stop_event.is_set():
        raise(TimeLimitExceededException(f'Brad error: time limit exceeded...')) 

    if i not in visits:
        visits[i] = len(visits)

    max_visit_0 = max(max_visit, visits[i])

    if any(robbed[j] > 0 for j in graph[i] if robbed[j] is not None): # check if there is any neighborhood robbed, among visited
        modes = ['not rob'] # if any, then decide not to rob the current node
    else:
        modes = ['not rob', 'rob'] # if there is no neighborhood robbed, then there are two options: do not rob, or rob

    # max_val = 0
    max_val = float('-inf')
    idxs = []
    for mode in modes:
        robbed[i] = 1 if mode == 'rob' else 0
        max_visit = max_visit_0 # initialize
        sum_val = values[i] if mode == 'rob' else 0 # initialize
        if get_matches:
            idxs_0 = [[i]] if mode == 'rob' else [[]] # initialize

        for j in graph[i]:
            if j == prev: # if j is the previouis 
                continue
            elif (j not in visits) or (visits[j] == max_visit + 1): # explore unvisited nodes or visit nodes in the same order
                # print(f'{i} --> {j} [OK]')
                out = dfs_3(j, prev=i, max_visit=max_visit, visits=visits, graph=graph, robbed=robbed, values=values, get_matches=get_matches, threading_stop_event=threading_stop_event)
                max_visit = max(max_visit, out['max_visit'])
                sum_val += out['max_val']
                if get_matches:
                    idxs_0 = [ii1 + ii2 for ii1 in idxs_0 for ii2 in out['idxs']]

            elif visits[i] > visits[j]: # previously visits node: low rank contact
                # print(f'{i} --> {j} [Low rank contact]')
                pass
            elif visits[i] < visits[j]: # previously visits node: high rank contact
                # print(f'{i} --> {j} [High rank contact]')
                pass
            else:
                raise(Exception('Brad error: impossible case, unless a self loop is allowed...'))

        # max_val = max(max_val, sum_val)
        if max_val < sum_val:
            max_val = sum_val # replace
            if get_matches:
                idxs = idxs_0 # replace
        elif max_val == sum_val:
            if get_matches:
                idxs.extend(idxs_0) # add

    robbed[i] = None # reset
    return {'max_visit':max_visit, 'max_val':max_val, 'idxs':idxs}

# if __name__=='__main__':
#     values = [1,1,1,1]
#     edges = [[0,1],[1,2],[2,3]]

#     # values = [0,1,2,3,4,5,6]
#     # edges = [
#     #     [0,1],[1,2],[2,3],[3,1],[3,0],[0,4],[4,5],[4,6],[0,6],
#     # ]

#     # values = [5, 2, 1, 1, 2, 12, 2, 2, 2, 1, 1, 1, 1, 2, 2, 7, 2, 2, 2, 1, 1, 1, 1, 1, 3]
#     # edges = [[0, 1], [0, 2], [0, 3], [0, 4], [0, 13], [0, 14], [1, 2], [1, 3], [1, 5], [1, 15], [1, 22], [2, 3], [2, 24], [3, 24], [4, 5], [4, 7], [4, 8], [4, 10], [4, 11], [4, 12], [4, 13], [4, 14], [5, 6], [5, 7], [5, 8], [5, 9], [5, 10], [5, 11], [5, 12], [5, 15], [5, 22], [5, 23], [6, 7], [6, 8], [6, 16], [6, 17], [6, 18], [7, 8], [7, 9], [7, 10], [7, 11], [7, 12], [7, 16], [7, 17], [7, 18], [8, 10], [8, 11], [8, 12], [8, 16], [8, 17], [8, 18], [9, 10], [9, 19], [9, 24], [10, 19], [10, 24], [11, 12], [11, 20], [11, 24], [12, 21], [12, 24], [13, 14], [13, 15], [13, 17], [13, 18], [13, 19], [13, 20], [13, 21], [14, 15], [14, 18], [14, 19], [14, 20], [14, 21], [15, 16], [15, 17], [15, 18], [15, 19], [15, 20], [15, 21], [15, 22], [15, 23], [16, 17], [16, 18], [17, 18], [18, 19], [18, 20], [18, 21], [19, 24], [20, 21], [20, 24], [21, 24], [22, 23], [22, 24], [23, 24]]

#     graph = {}
#     for i,j in edges:
#         graph.setdefault(i, []).append(j)
#         graph.setdefault(j, []).append(i)
#     print(f'graph = {graph}')

#     # visits={}
#     # out = dfs(0, prev=-1, max_visit=-1, visits=visits, graph=graph)
#     # print(out)
#     # # dfs(1, prev=-1, max_visit=-1, visits=visits, graph=graph)

#     print(f'values = {values}')
#     robbed = [None]*len(values)
#     print(f'robbed = {robbed}')
#     for i in range(1):
#         # out2 = dfs_3(i, prev=-1, max_visit=-1, visits={}, graph=graph, robbed=robbed, values=values, get_matches=False)
#         out2 = dfs_3(i, prev=-1, max_visit=-1, visits={}, graph=graph, robbed=robbed, values=values, get_matches=True)
#         print(out2)

# %%
def get_max_house_robbery(values, edges, get_matches=False, debug=False, threading_stop_event=None):
    num_points = len(values)

    graph = {i:[] for i in range(len(values))}
    for i,j in edges:
        graph.setdefault(i, []).append(j)
        graph.setdefault(j, []).append(i)

    if debug:
        print(f'graph = {graph}')

    #--- find disjoint sets -------------------------
    djs = Union_Find(num_points, edges) # disjoin sets

    i_roots = set()
    for i in range(num_points):
        r = djs.find_root(i) # to make sure there is only one root for each group
        i_roots.add(r)

    if debug:
        print(f'i_roots = {i_roots}')

    #--------------------------------------
    robbed = [None]*len(values)
    if debug:
        print(f'robbed = {robbed}')

    # max_vals = []
    # for i in i_roots:
    #     out2 = dfs_2(i, prev=-1, max_visit=-1, visits={}, graph=graph, robbed=robbed, values=values, threading_stop_event=threading_stop_event)
    #     max_vals.append(out2['max_val'])

    # return sum(max_vals)

    max_vals = []
    idxs = [[]]
    for i in i_roots:
        out2 = dfs_3(i, prev=-1, max_visit=-1, visits={}, graph=graph, robbed=robbed, values=values, get_matches=get_matches, threading_stop_event=threading_stop_event)
        max_vals.append(out2['max_val'])
        if get_matches:
            idxs = [ii1 + ii2 for ii1 in idxs for ii2 in out2['idxs']]
 
    if not get_matches:
        idxs = None # reset
 
    return {'max_val':sum(max_vals), 'matches':idxs}

if __name__=='__main__':
    values = [1,2,3]
    edges = []
    #--- 1-d problem ----------------------
    # values = [1,2,3,1,9] # answer: 13
    # edges = [[i,i+1] for i in range(len(values)-1)]
    #---- complete connection -------------
    # values = [i for i in range(15)] # answer: 14 = (15 - 1)
    # edges = [[i,j] for i in range(len(values)) for j in range(i+1, len(values))]
    #--- only diamond -----------------------------------
    # values = [1,2,6,3] # answer: 7 (= 1 + 6)
    # edges = [[0,1],[1,2],[0,3],[1,3],[2,3]]
    #--- diamond and line -----------------------------------
    # values = [1,2,6,3,     1,3,4] # 12
    # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [4,5],[5,6]]
    # #---diamond with line -----------------------------------
    # values = [1,2,6,3, 1,2] # 9
    # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [2,4],[4,5]]
    #--- two diamonds with line -----------------------------------
    # values = [1,2,6,3,   3,1,2,   1,2] # 10
    # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],   [2,4],[2,6],[4,6],[4,5],[5,6],     [2,7],[7,8]]
    #--- diamond and line -----------------------------------
    # values = [1,2,6,3,     1,3,4,     1,2,6,3,     ]
    # edges = [[0,1],[1,2],[0,3],[1,3],[2,3],     [4,5],[5,6],    [7,8],[8,9],[7,10],[8,10],[9,10], ]
    #--------------------------------------

    # out = get_max_house_robbery(values, edges, get_matches=False, debug=False)
    out = get_max_house_robbery(values, edges, get_matches=True, debug=False)
    print(f'out = {out}')
# Out:
# out = {'max_val': 6, 'matches': [[0, 1, 2]]}

# %% [markdown]
# ## Longest common token subsequence (Greedy & Brute force)

# %% [markdown]
# - helping functions

# %%
def is_word_char(c, word_char_set=set('0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')):
    return c in word_char_set

# if __name__=='__main__':
#     print(is_word_char('c'))
#     print(is_word_char('-'))
#     print(is_word_char('#'))

# %%
def find_tokens(text, word_char_set=set('0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')): # UPDATE: 2026-03-16
    #--- forward cumulutive sum of characters -----------------------
    csum = [0] * len(text) # initialize to zeros
    for i in range(len(text)-1, -1, -1):
        if is_word_char(text[i], word_char_set=word_char_set):
            if i == len(text)-1: # if the very last charcter
                csum[i] = 1
            else:
                csum[i] = csum[i+1] + 1

    #--- token connectivity = root ----------------------------------
    root = [None] * len(text)
    iroot, cnt = {}, 0
    for i in range(len(text)):
        if is_word_char(text[i], word_char_set=word_char_set):
            if i == 0 or not is_word_char(text[i-1], word_char_set=word_char_set): # if the initial character of each token
                i_initial = i
                iroot[i], cnt = cnt, cnt + 1
            root[i] = i_initial

    return csum, root, iroot

# if __name__=="__main__":
#     print(find_tokens('hello world!'))
#     # ([5, 4, 3, 2, 1, 0, 5, 4, 3, 2, 1, 0], [0, 0, 0, 0, 0, None, 6, 6, 6, 6, 6, None], {0: 0, 6: 1})

# %% [markdown]
# - main

# %%
@use_threading_stop_event
def longest_common_token_subsequence( # UPDATE: 2026-05-02
    text1, text2,
    word_char_set=set('0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'),
    get_matches=False,
    allow_tail_nonmatch=True,
    allow_middle_nonmatch=True,
    include_intial_match=False, # if turned on, it partially covers the loophole of greedy approach: e.g. USA vs United States of America
    on_greedy_matching=True, # there is no impact on the number of matching characters, but if turned on, all possible matching combinations may not be obtained
    debug=False, 
    time_limit_sec=None, threading_stop_event=None, threading_outputs=[None],
    ):

    csum1, root1, iroot1 = find_tokens(text1, word_char_set=word_char_set)
    csum2, root2, iroot2 = find_tokens(text2, word_char_set=word_char_set)

    all_matches = []
    all_matches_full = {}
    matches_dict = {}
    seen_i, seen_j = set(), set()
    #-------------------------------------------------------------------
    cnt_complete_matches = 0
    for i in iroot1.keys():
        for j in iroot2.keys():
            _text1_ = text1[i:(i + csum1[i])]
            _text2_ = text2[j:(j + csum2[j])]

            val, trie = lcs(0, 0, _text1_, _text2_, dp={}) # partially greedy approach

            matches = []
            flatten_trie_node(trie, [], matches)
            # print(f'_text1_ = {_text1_}, _text2_ = {_text2_}, matches = {matches}')

            matches_dict[(i,j)] = (val, matches) # save for later use

            if on_greedy_matching:
                if (i not in seen_i) and (j not in seen_j) and (val > 0) and (val == len(_text1_) == len(_text2_)): # complete match between two texts
                    pairs = matches[0] # len(matches) == 1 is always guaranteed with the above condition

                    (x0, y0), (x1, y1) = pairs[0], pairs[-1] # only top left & bottom right points (rectangle)
                    xyxy_val_ij = (i+x0, j+y0, i+x1, j+y1, val, i, j)

                    all_matches.append(xyxy_val_ij) # add complete matches

                    if get_matches:
                        all_matches_full.setdefault(xyxy_val_ij, []).append([(i+x, j+y) for x,y in pairs])

                    seen_i.add(i)
                    seen_j.add(j)

                    cnt_complete_matches += 1

    #--- token-by-token longest common subsequence: greedy for each token-token pair --------------------------------------
    seen = set()
    for i in iroot1.keys():
        if i in seen_i:
            continue

        for j in iroot2.keys():
            if j in seen_j:
                continue

            # _text1_ = text1[i:(i + csum1[i])]
            # _text2_ = text2[j:(j + csum2[j])]

            # val, trie = lcs(0, 0, _text1_, _text2_, dp={}) # partially greedy approach

            # matches = []
            # flatten_trie_node(trie, [], matches)
            # # print(f'_text1_ = {_text1_}, _text2_ = {_text2_}, matches = {matches}')

            val, matches = matches_dict[(i,j)]

            for pairs in matches:
                # if pairs:
                    # all_matches.append([(i+x, j+y) for x,y in pairs])
                if (
                    pairs
                    # and (allow_head_nonmatch or not (pairs[0][0] != 0 and pairs[0][1] != 0)) # '__xxyyz..' vs '_____xxyyz..'
                    and (pairs[0][0] == 0 or pairs[0][1] == 0) # exclude this match: e.g. 'xxxAAyyy' vs 'zzAAwww', but this is okay: 'AAyyy' vs 'zzAAwww'
                    and (allow_tail_nonmatch or not (pairs[-1][0] != csum1[i] - 1 and pairs[-1][1] != csum2[j] - 1)) # '..xxyyz__' vs '..xxyyz_____'
                    and (allow_middle_nonmatch or not (pairs[-1][0] - pairs[0][0] + 1 > len(pairs) and pairs[-1][1] - pairs[0][1] + 1 > len(pairs))) # '..x_y___z....' vs '....x____y_z.....'
                    ):

                    (x0, y0), (x1, y1) = pairs[0], pairs[-1] # only top left & bottom right points (rectangle)
                    xyxy_val_ij = (i+x0, j+y0, i+x1, j+y1, val, i, j)
                    if xyxy_val_ij not in seen:
                        all_matches.append(xyxy_val_ij)
                        seen.add(xyxy_val_ij)

                    if include_intial_match:
                        x0y0x0y0_val_ij = (i+x0, j+y0, i+x0, j+y0, 1, i, j)
                        if x0y0x0y0_val_ij not in seen:
                            all_matches.append(x0y0x0y0_val_ij)
                            seen.add(x0y0x0y0_val_ij)

                    if get_matches:
                        all_matches_full.setdefault(xyxy_val_ij, []).append([(i+x, j+y) for x,y in pairs])

                        if include_intial_match and (x0y0x0y0_val_ij not in all_matches_full):
                            all_matches_full.setdefault(x0y0x0y0_val_ij, []).append([(i+x0, j+y0)])

    if debug:
        print(f'len(all_matches) = {len(all_matches)}')
        # print(f'all_matches = {all_matches}')

    #-----------------
    # values = []
    values = [val for _, _, _, _, val, _, _ in all_matches]
    edges = []
    # for i in range(len(all_matches)):
    for i in range(cnt_complete_matches, len(all_matches)): # skip the complete match cases, if the greedy approach is turned on
        x0, y0, x1, y1, val, ri, rj = all_matches[i]
        # values.append(val)

        for j in range(i+1, len(all_matches)):
            # if i == j:
            #     continue

            a0, b0, a1, b1, _, si, sj = all_matches[j]

            if (x0 <= a1 and a0 <= x1) or (y0 <= b1 and b0 <= y1): # if there is any overlap on either x-axis OR y-axis
                edges.append([i,j])
            elif (ri == si) and (rj == sj): # if there is no ovelap between two recangles, but they are in the same token, then they can not co-exist
                edges.append([i,j])

    if debug:
        print(f'len(values) = {len(values)}')
        # print(f'values = {values}')
        print(f'len(edges) = {len(edges)}')
        # print(f'edges = {edges}')

    #-----------------
    out = get_max_house_robbery(values, edges, get_matches=get_matches, debug=False, threading_stop_event=threading_stop_event)
    if debug:
        print(f'out = {out}')

    # --- find matched results ------------------------------------------------------------------
    if get_matches:
        outs = []
        for one_matches in out['matches']:
            option_all = [[]]
            for i in one_matches:
                option_all = [ii1 + [(i,j)] for ii1 in option_all for j in range(len(all_matches_full[all_matches[i]]))] # find all possible combinations
 
            for option in option_all:
                match1, match2 = [-1]*len(text1), [-1]*len(text2) # initialize
                # for k, i in enumerate(option):
                for k, (i,j) in enumerate(option):
                    # pairs = all_matches[i]
                    pairs = all_matches_full[all_matches[i]][j]
                    for x, y in pairs:
                        if match1[x] < 0:
                            match1[x] = k
                        else:
                            raise(Exception('Brad error: a critical issue occurred. There is an overlap...'))
                      
                        if match2[y] < 0:
                            match2[y] = k
                        else:
                            raise(Exception('Brad error: a critical issue occurred. There is an overlap...'))
 
                outs.append({'match1':match1, 'match2':match2,})
    else:
        outs = None

    output = {'csum1':csum1, 'root1':root1, 'iroot1':iroot1, 'csum2':csum2, 'root2':root2, 'iroot2':iroot2, 'num_matches': out['max_val'], 'matches':outs} # UPDATE: 2026-04-15

    threading_outputs[0] = output
    return output

# if __name__=='__main__':
#     text1 = 'abcabc'
#     text2 = 'abc abc'
#     # text1 = 'aaaaaaaaaaaaaaaaaaa'
#     # text2 = 'aaa aaa aaaaaaaaa aaa aa'
#     # text1, text2 = ('Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3', 'Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4')
#     # text1 = '1122'
#     # text2 = '22 11'
#     text1 = '1122'
#     text2 = '2211'

#     # out = longest_common_token_subsequence(text1.lower(), text2.lower(), debug=True)
#     out = longest_common_token_subsequence(text1.lower(), text2.lower(), time_limit_sec=5, debug=True)
#     print(out)
#     if out is not None:
#         print(f"num_matches = {out['num_matches']}")

# %% [markdown]
# # Post-processing Fuctions

# %% [markdown]
# ## token_matched_all_or_partial_but_in_full

# %%
def token_matched_all_or_partial_but_in_full(root1, match1):
    rcnt, mcnt = {}, {}
    for r, m in zip(root1, match1):
        if r is not None:
            if r not in rcnt:
                rcnt[r] = 0
            if r not in mcnt:
                mcnt[r] = 0
                
            rcnt[r] += 1
            if m >= 0:
                mcnt[r] += 1

    perfect_matched = all(mcnt[k] == v for k,v in rcnt.items())
    partial_token_matched = all(mcnt[k]==0 or mcnt[k] == v for k,v in rcnt.items())
    return perfect_matched, partial_token_matched

# %% [markdown]
# ## count_consecutive_initials

# %%
def count_consecutive_initials(ii, i_not_set):
    conn = [0] * len(ii)
    for k,v in ii.items():
        if k not in i_not_set:
            conn[v] = 1

    cnt = 0
    for i in range(len(conn)):
        if conn[i] > 0 and (i == 0 or conn[i-1] == 0):
            cnt += 1

    return cnt

# %% [markdown]
# ## is_two_texts_same

# %%
def is_two_texts_same(csum1, iroot1, match1, csum2, iroot2, match2):
    ii_remaining_1 = set(iroot1.keys()).intersection([i for i, (t,m) in enumerate(zip(csum1, match1)) if t > 0 and m < 0]) # if token and not assigned
    ii_remaining_2 = set(iroot2.keys()).intersection([i for i, (t,m) in enumerate(zip(csum2, match2)) if t > 0 and m < 0]) # if token and not assigned            

    cnt1 = count_consecutive_initials(iroot1, ii_remaining_1)
    cnt2 = count_consecutive_initials(iroot2, ii_remaining_2)

    is_same = (
        (len(ii_remaining_1) == 0 and (len(iroot1) <= len(iroot2) - len(ii_remaining_2))) or
        (len(ii_remaining_2) == 0 and (len(iroot2) <= len(iroot1) - len(ii_remaining_1)))
        ) and (cnt1 == 1 and cnt2 == 1)
    return is_same

# %% [markdown]
# ## get_impurity_score

# %%
def get_impurity_score(arr, type=['Gini','Entropy'][1]): # https://datasciencedojo.com/blog/gini-index-and-entropy/
    import math

    Ps = {}
    for c in arr:
        if c not in Ps:
            Ps[c] = 0
        Ps[c] += 1.0 / len(arr)

    if type == 'Gini':
        score = 1
        for c,p in Ps.items():
            score -= p**2

    elif type == 'Entropy':
        score = 0
        for c,p in Ps.items():

            score += -p*math.log2(p)
    else:
        raise(ValueError)

    return score

# if __name__=='__main__':
#     print(get_impurity_score([1,1,1,1,1,1], type=['Gini','Entropy'][0])) # 0
#     print(get_impurity_score([1,1,1,3,3,3], type=['Gini','Entropy'][0])) # 0.5
#     print(get_impurity_score([1,1,2,2,3,3], type=['Gini','Entropy'][0])) # 0.6666666666666665
#     print(get_impurity_score([1,1,1,1,1,1], type=['Gini','Entropy'][1])) # 0
#     print(get_impurity_score([1,1,1,3,3,3], type=['Gini','Entropy'][1])) # 1.0
#     print(get_impurity_score([1,1,2,2,3,3], type=['Gini','Entropy'][1])) # 1.584962500721156

# %% [markdown]
# ## get_average_impurity_score

# %%
def get_average_impurity_score(root, match, type=['Gini','Entropy'][1]):
    arrs = {}
    for r, m in zip(root, match):
        if (r is not None) and (m >= 0):
            arrs.setdefault(r,[]).append(m)

    scores, cnts = [], []
    for arr in arrs.values():
        scores.append(get_impurity_score(arr, type=type))
        cnts.append(len(arr))

    if cnts:
        score = 1.0 * sum(c*s for c,s in zip(cnts,scores)) / sum(cnts)
    else:
        score = 0

    return score

# %% [markdown]
# ## log_matched_results

# %%
def log_matched_results(text1, text2, match1, match2):
    match_out1 = f"{text1}\n{''.join(['^' if n >=0 else ' ' for n in match1])}\n{''.join([chr(ord('A')+n) if n >=0 else ' ' for n in match1])}"
    match_out2 = f"{text2}\n{''.join(['^' if n >=0 else ' ' for n in match2])}\n{''.join([chr(ord('A')+n) if n >=0 else ' ' for n in match2])}"
    log = f'{match_out1}\n{match_out2}'
    return log

# %% [markdown]
# ## all_tokens_matched_full_or_none

# %%
def all_tokens_matched_full_or_none(root1, match1):
    rcnt, mcnt = {}, {}
    for r, m in zip(root1, match1):
        if r is not None:
            if r not in rcnt:
                rcnt[r] = 0 # initialize
            if r not in mcnt:
                mcnt[r] = 0 # initialize

            rcnt[r] += 1
            if m >= 0: # only if match found
                mcnt[r] += 1

    matched_full_or_none = all(mcnt[k] == n or mcnt[k]==0 for k,n in rcnt.items())
    return matched_full_or_none

# %% [markdown]
# ## all_tokens_matched_full_or_purely_partial_from_initial

# %%
def all_tokens_matched_full_or_purely_partial_from_initial(root1, match1):
    rcnt, mcnt, ucnt, icnt = {}, {}, {}, {}
    for i, (r, m) in enumerate(zip(root1, match1)):
        if r is not None:
            if r not in rcnt:
                rcnt[r] = 0 # initialize
            if r not in mcnt:
                mcnt[r] = 0 # initialize
            if r not in ucnt:
                ucnt[r] = set() # initialize
            if r not in icnt:
                icnt[r] = 0 # initialize

            rcnt[r] += 1
            if m >= 0: # only if match found
                mcnt[r] += 1
                ucnt[r].add(m)
                if i == r: # i.e. if initial of token is matched
                    icnt[r] += 1

    # matched_full_or_purely_partial_from_initial = all(mcnt[k] == n or len(ucnt[k]) in [0,1] for k,n in rcnt.items())
    matched_full_or_purely_partial_from_initial = all(mcnt[k] == n or len(ucnt[k]) == 0 or (len(ucnt[k]) == 1 and icnt[k] > 0) for k,n in rcnt.items())
    return matched_full_or_purely_partial_from_initial

# %% [markdown]
# # Real-world Applications

# %% [markdown]
# ## compare_entity_names

# %%
def compare_entity_names(text1, text2, detect_typos=False, case_sensitive=False, time_limit_sec=15):
    _text1_ = text1 if case_sensitive else text1.lower()
    _text2_ = text2 if case_sensitive else text2.lower()
    out = longest_common_token_subsequence(_text1_, _text2_, get_matches=True, allow_tail_nonmatch=True, allow_middle_nonmatch=detect_typos, include_intial_match=True, on_greedy_matching=True, time_limit_sec=time_limit_sec) # only words

    if out is not None:
        matched_full_or_purely_partial_from_initial = False

        _log_ = []
        for _, row in enumerate(out['matches']):
            matched_full_or_purely_partial_from_initial |= all_tokens_matched_full_or_purely_partial_from_initial(out['root1'], row['match1']) and all_tokens_matched_full_or_purely_partial_from_initial(out['root2'], row['match2'])

            log = log_matched_results(text1, text2, row['match1'], row['match2'])
            _log_.append(log)
        logs = '\n------------------------------------------------------------------------------\n'.join(_log_)

        score1 = out['num_matches'] / sum(r is not None for r in out['root1'])
        score2 = out['num_matches'] / sum(r is not None for r in out['root2'])
        score_min = min(score1, score2)
        score_max = max(score1, score2)
        score_avg = 0.5*(score1 + score2)

    else:
        matched_full_or_purely_partial_from_initial = None
        logs = None
        score1, score2 = None, None
        score_min = None
        score_max = None
        score_avg = None

    return {
        'matched_full_or_purely_partial_from_initial':matched_full_or_purely_partial_from_initial,
        'details':logs,
        'score1':score1,
        'score2':score2,
        'score_min':score_min,
        'score_max':score_max,
        'score_avg':score_avg,
        }

# %% [markdown]
# ## compare_addresses

# %%
import re

def compare_addresses(text1, text2, case_sensitive=False, SCORE_THRESHOLD=0.5, SCORE_THRESHOLD_LCS=0.5, time_limit_sec=15):
    address1 = text1 if case_sensitive else text1.lower()
    address2 = text2 if case_sensitive else text2.lower()
                
    nums1, chars1 = re.sub(r'[^\d]+', ' ', address1).strip(), re.sub(r'[^a-zA-Z]+', ' ', address1).strip()
    nums2, chars2 = re.sub(r'[^\d]+', ' ', address2).strip(), re.sub(r'[^a-zA-Z]+', ' ', address2).strip()

    out_final = { # initialize
        'score_min': None, # only number
        'score_max': None, # only number
        'matched_full_or_none': None, # only number
        'score_mean':None, # only characters
        'matched_full_or_purely_partial_from_initial':None, # only characters
        'score_lcs_mean':None, # only characters
        'score_typo_mean':None, # typo
        }

    #--- CONDITION 1: ONLY NUMBERS ------------------------------------------------------------------------
    if nums1 and nums2:
        out = longest_common_token_subsequence(nums1, nums2, allow_tail_nonmatch=False, allow_middle_nonmatch=False, get_matches=True, time_limit_sec=time_limit_sec) # only number            

        score1 = out['num_matches'] / sum(r is not None for r in out['root1'])
        score2 = out['num_matches'] / sum(r is not None for r in out['root2'])

        score_min = min(score1, score2)
        score_max = max(score1, score2)
        matched_full_or_none = any(all_tokens_matched_full_or_none(out['root1'], row['match1']) and all_tokens_matched_full_or_none(out['root2'], row['match2']) for row in out['matches'])

        if (score_max == 1) and matched_full_or_none: # if one is inclusive to the other
            out_final['score_min'] = score_min
            out_final['score_max'] = score_max
            out_final['matched_full_or_none'] = matched_full_or_none
            pass
        else:
            return out_final
    elif (not nums1) and (not nums2): # if both have no digits
        out_final['score_min'] = 'N/A'
        out_final['score_max'] = 'N/A'
        out_final['matched_full_or_none'] = 'N/A'
        pass
    else:
        return out_final

    #--- CONDITION 2: ONLY ALPHABET CHARACTERS ------------------------------------------------------------
    out = longest_common_token_subsequence(chars1, chars2, allow_tail_nonmatch=True, allow_middle_nonmatch=True, get_matches=True, time_limit_sec=time_limit_sec) # only words

    if out is not None:
        score1_char = out['num_matches'] / sum(r is not None for r in out['root1'])
        score2_char = out['num_matches'] / sum(r is not None for r in out['root2'])

        score_mean = 0.5*(score1_char + score2_char)
        matched_full_or_purely_partial_from_initial = any(all_tokens_matched_full_or_purely_partial_from_initial(out['root1'], rr['match1']) and all_tokens_matched_full_or_purely_partial_from_initial(out['root2'], rr['match2']) for rr in out['matches'])

        if score_mean >= SCORE_THRESHOLD: # if character score is greater than 80%
            out_final['score_mean'] = score_mean
            out_final['matched_full_or_purely_partial_from_initial'] = matched_full_or_purely_partial_from_initial

            out_typo = longest_common_token_subsequence(chars1, chars2, allow_tail_nonmatch=True, allow_middle_nonmatch=False, get_matches=False, time_limit_sec=time_limit_sec) # only words: for typo detection
            score1_typo = out_typo['num_matches'] / sum(r is not None for r in out_typo['root1'])
            score2_typo = out_typo['num_matches'] / sum(r is not None for r in out_typo['root2'])
            score_typo_mean = 0.5*(score1_typo + score2_typo)

            out_final['score_typo_mean'] = score_typo_mean

            pass
        else:
            return out_final

    else: # if time limit error occured, then try longest common subsequence algorithm with lower score threshold
        #--- longest common subsequence ------------------------------------------------------------------
        address1_no_space = re.sub('[^0-9a-zA-Z]', '', address1).strip()
        address2_no_space = re.sub('[^0-9a-zA-Z]', '', address2).strip()

        max_val = longest_common_subsequence(address1_no_space, address2_no_space)

        score_lcs_mean = 0.5*(max_val/len(address1_no_space) + max_val/len(address2_no_space))

        if score_lcs_mean >= SCORE_THRESHOLD_LCS: # if character score is greater than 80%
            out_final['score_lcs_mean'] = score_lcs_mean
            pass
        else:
            return out_final

    return out_final

# %% [markdown]
# # TEST

# %%
if __name__=='__main__':
    import time

    for text1, text2 in [
        # ('abc', 'abcabc'),
        # ('abc abc', 'abcabc'),
        # ('abc', 'aabbcc'),
        # ('abc abc', 'aabbcc'),
        # ('abc', 'aaaaaabc'),
        # ('xab', 'axb'),
        # ('axbc', 'abcx'),
        # ('abc abc', 'abcabcxa'),
        # ('aecxef ghi', 'aec xef ghi'),
        ('aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa','aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa'), # exceeds time limit, if on_greedy_matching = False
        ('111222 333444', '111 222333 444'),

        ('Alan Turing', 'Alan Mathison Turing'),
        ('Albert Einstein', 'Einstein, Albert'),
        ('Tom Edison', 'Thomas Edison'),
        ('Bomsoo Kim', 'Bom Soo Kim'),
        ('Bomsoo Kim', 'Kim, Bom-soo'),
        ('Bomsoo Kim', 'Bomsoo P. Kim'),
        ('Bomsoo Peter Kim', 'Bomsoo P. Kim'),
        ('Brad Kim', 'Bomsoo Kim'),
        ('Brad Pitt', 'Bomsoo Kim'),
        ('Bomsoo Kim', 'Bonsoo Kim'), # can detect typos. To disable this, need to set allow_middle_nonmatch=False
        ('Bomsoo Kim', 'Nomsoo Kim'),
        ('Bomsoo Brad Kim', 'B.B.Kim'),
        ('Bomsoo Brad Kim', 'BBKim'), # for match, need to set include_intial_match=True
        ('Tingting Wong', 'Ting Ting Wong'),
        ('Yun Ying Jin', 'Yunying Jin'),
        ('International I. Company Ltd', 'Int. Inn Co. Limited'),
        ('International Inn Company Ltd', 'I. I. Co. Limited'),
        ('Green Construction Corporation Ltd.', 'Green Construction Co., Limited'),
        ('United States of America', 'U.S.A.'),
        ('United States of America', 'USA'), # for match, need to set include_intial_match=True
        ('New York, NY ', 'NY, NY'),
        ('1122 Hunter St.','11 22 Hunter St.'),
        ('1122 Hunter St.','22 11 Hunter St.'),
        ('1122 Hunter St.','2211 Hunter St.'),
        ('Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3', 'Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4'),
        # ('Empire State Building, 20 W 34th St., New York, NY 10001 United States of America (Tel. 123-456-7890)', '20 WEST 34TH STREET, EMPIRE STATE BLD. 44TH FLOOR ROOM#2, NY, NY 10001-00000 U.S.A.'), # !!!!!!!!!!!!!!!! NY needs to be captured
 
        # ('12 3','1 32'), # for non-match, need to set allow_tail_nonmatch=False, allow_middle_nonmatch=False
        # ('012 3','01 32'), # for non-match, need to set allow_tail_nonmatch=False, allow_middle_nonmatch=False
        # ('301 1 38','31 8'), # for non-match, need to set allow_tail_nonmatch=False, allow_middle_nonmatch=False
        # ('17 102','1102 7'), # for non-match, need to set allow_tail_nonmatch=False, allow_middle_nonmatch=False
        # ('14032 5','140 35 2'), # for non-match, need to set allow_tail_nonmatch=False, allow_middle_nonmatch=False
        # ('1304 2','6 30 32 42 1 10'),
        # # ('STREET','ST APT E'),
        # # ('dist chengdu','district'),
        ]:

        print(f'##############################################################################################################################')
        tic = time.time()
        # out = longest_common_token_subsequence(text1.lower(), text2.lower())
        out = longest_common_token_subsequence(text1.lower(), text2.lower(), get_matches=True, on_greedy_matching=True, time_limit_sec=15, debug=False)
        # out = longest_common_token_subsequence(text1.lower(), text2.lower(), get_matches=True, on_greedy_matching=False, time_limit_sec=15, debug=False)
        # out = longest_common_token_subsequence(text1.lower(), text2.lower(), get_matches=True, allow_tail_nonmatch=True, allow_middle_nonmatch=True, include_intial_match=False, on_greedy_matching=True, time_limit_sec=15, debug=False)
        # out = longest_common_token_subsequence(text1.lower(), text2.lower(), get_matches=True, allow_tail_nonmatch=True, allow_middle_nonmatch=True, include_intial_match=True, on_greedy_matching=True, time_limit_sec=15, debug=False)
        # out = longest_common_token_subsequence(text1.lower(), text2.lower(), get_matches=True, allow_tail_nonmatch=False, allow_middle_nonmatch=False, include_intial_match=False, on_greedy_matching=True, time_limit_sec=15, debug=False)        
        toc = time.time()

        # score1 = out['num_matches'] / sum(r is not None for r in out['root1'])
        # score2 = out['num_matches'] / sum(r is not None for r in out['root2'])
        # score_mean = 0.5*(score1 + score2)

        for i, row in enumerate(out['matches']):
            log = log_matched_results(text1, text2, row['match1'], row['match2'])

            score1 = sum(n>=0 for n in row['match1']) / sum(r is not None for r in out['root1'])
            score2 = sum(n>=0 for n in row['match2']) / sum(r is not None for r in out['root2'])

            #------------------------------------------------------------------------------------------------
            # is_same = is_two_texts_same(out['csum1'], out['iroot1'], row['match1'], out['csum2'], out['iroot2'], row['match2'])

            # perfect_matched1, partial_token_matched1 = token_matched_all_or_partial_but_in_full(out['root1'], row['match1'])
            # perfect_matched2, partial_token_matched2 = token_matched_all_or_partial_but_in_full(out['root2'], row['match2'])

            matched_full_or_none1 = all_tokens_matched_full_or_none(out['root1'], row['match1'])
            matched_full_or_none2 = all_tokens_matched_full_or_none(out['root2'], row['match2'])

            matched_full_or_purely_partial_from_initial1 = all_tokens_matched_full_or_purely_partial_from_initial(out['root1'], row['match1'])
            matched_full_or_purely_partial_from_initial2 = all_tokens_matched_full_or_purely_partial_from_initial(out['root2'], row['match2'])

            print(f"---- [{i+1}/{len(out['matches'])}] ---------------------------------------------------")
            print(log)
            print()
            print(f"score1 = {score1}, score2 = {score2}, avg(scores) = {0.5*(score1 + score2)}")
            print(f"num_matches_1 = {sum(n>=0 for n in row['match1'])}")
            print(f"num_matches_2 = {sum(n>=0 for n in row['match2'])}")
            #------------------------------------------------------------------------------------------------
            # print(f'RESULT: is_same = {is_same}')
            # print(f'RESULT: {partial_token_matched1 and partial_token_matched2 and (perfect_matched1 or perfect_matched2)}')
            print(f'RESULT: matched_full_or_none1 & matched_full_or_none2 = {matched_full_or_none1 and matched_full_or_none2}')
            print(f'RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = {matched_full_or_purely_partial_from_initial1 and matched_full_or_purely_partial_from_initial2}')

        print(f'\nTIME ELAPSED = {toc - tic} sec')
# Out:
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa
# ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^
# AAA BBB CCC DDD EEE FFF GGG HHH III JJJ
# aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa
# ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^ ^^^
# AAA BBB CCC DDD EEE FFF GGG HHH III JJJ
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 30
# num_matches_2 = 30
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.002997875213623047 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# 111222 333444
# ^^^^^^ ^^^^^^
# AAABBB CCCDDD
# 111 222333 444
# ^^^ ^^^^^^ ^^^
# AAA BBBCCC DDD
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 12
# num_matches_2 = 12
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0010025501251220703 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Alan Turing
# ^^^^ ^^^^^^
# AAAA BBBBBB
# Alan Mathison Turing
# ^^^^          ^^^^^^
# AAAA          BBBBBB
#
# score1 = 1.0, score2 = 0.5555555555555556, avg(scores) = 0.7777777777777778
# num_matches_1 = 10
# num_matches_2 = 10
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0009996891021728516 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Albert Einstein
# ^^^^^^ ^^^^^^^^
# AAAAAA BBBBBBBB
# Einstein, Albert
# ^^^^^^^^  ^^^^^^
# BBBBBBBB  AAAAAA
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 14
# num_matches_2 = 14
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0020074844360351562 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Tom Edison
# ^^^ ^^^^^^
# BBB AAAAAA
# Thomas Edison
# ^ ^^   ^^^^^^
# B BB   AAAAAA
#
# score1 = 1.0, score2 = 0.75, avg(scores) = 0.875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0009031295776367188 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Kim
# ^^^^^^ ^^^
# BBBCCC AAA
# Bom Soo Kim
# ^^^ ^^^ ^^^
# BBB CCC AAA
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0012202262878417969 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Kim
# ^^^^^^ ^^^
# BBBCCC AAA
# Kim, Bom-soo
# ^^^  ^^^ ^^^
# AAA  BBB CCC
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0005521774291992188 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Kim
# ^^^^^^ ^^^
# AAAAAA BBB
# Bomsoo P. Kim
# ^^^^^^    ^^^
# AAAAAA    BBB
#
# score1 = 1.0, score2 = 0.9, avg(scores) = 0.95
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0010271072387695312 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Peter Kim
# ^^^^^^ ^     ^^^
# AAAAAA C     BBB
# Bomsoo P. Kim
# ^^^^^^ ^  ^^^
# AAAAAA C  BBB
#
# score1 = 0.7142857142857143, score2 = 1.0, avg(scores) = 0.8571428571428572
# num_matches_1 = 10
# num_matches_2 = 10
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Brad Kim
# ^    ^^^
# B    AAA
# Bomsoo Kim
# ^      ^^^
# B      AAA
#
# score1 = 0.5714285714285714, score2 = 0.4444444444444444, avg(scores) = 0.5079365079365079
# num_matches_1 = 4
# num_matches_2 = 4
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0009796619415283203 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Brad Pitt
# ^
# A
# Bomsoo Kim
# ^
# A
#
# score1 = 0.125, score2 = 0.1111111111111111, avg(scores) = 0.11805555555555555
# num_matches_1 = 1
# num_matches_2 = 1
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Kim
# ^^ ^^^ ^^^
# BB BBB AAA
# Bonsoo Kim
# ^^ ^^^ ^^^
# BB BBB AAA
#
# score1 = 0.8888888888888888, score2 = 0.8888888888888888, avg(scores) = 0.8888888888888888
# num_matches_1 = 8
# num_matches_2 = 8
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Bomsoo Kim
#        ^^^
#        AAA
# Nomsoo Kim
#        ^^^
#        AAA
#
# score1 = 0.3333333333333333, score2 = 0.3333333333333333, avg(scores) = 0.3333333333333333
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0009968280792236328 sec
# ##############################################################################################################################
# ---- [1/2] ---------------------------------------------------
# Bomsoo Brad Kim
# ^      ^    ^^^
# B      C    AAA
# B.B.Kim
# ^ ^ ^^^
# B C AAA
#
# score1 = 0.38461538461538464, score2 = 1.0, avg(scores) = 0.6923076923076923
# num_matches_1 = 5
# num_matches_2 = 5
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [2/2] ---------------------------------------------------
# Bomsoo Brad Kim
# ^      ^    ^^^
# B      C    AAA
# B.B.Kim
# ^ ^ ^^^
# C B AAA
#
# score1 = 0.38461538461538464, score2 = 1.0, avg(scores) = 0.6923076923076923
# num_matches_1 = 5
# num_matches_2 = 5
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/2] ---------------------------------------------------
# Bomsoo Brad Kim
#        ^    ^^^
#        A    BBB
# BBKim
#  ^^^^
#  ABBB
#
# score1 = 0.3076923076923077, score2 = 0.8, avg(scores) = 0.5538461538461539
# num_matches_1 = 4
# num_matches_2 = 4
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [2/2] ---------------------------------------------------
# Bomsoo Brad Kim
#        ^    ^^^
#        A    BBB
# BBKim
# ^ ^^^
# A BBB
#
# score1 = 0.3076923076923077, score2 = 0.8, avg(scores) = 0.5538461538461539
# num_matches_1 = 4
# num_matches_2 = 4
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/2] ---------------------------------------------------
# Tingting Wong
# ^^^^^^^^ ^^^^
# CCCCBBBB AAAA
# Ting Ting Wong
# ^^^^ ^^^^ ^^^^
# BBBB CCCC AAAA
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 12
# num_matches_2 = 12
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [2/2] ---------------------------------------------------
# Tingting Wong
# ^^^^^^^^ ^^^^
# BBBBCCCC AAAA
# Ting Ting Wong
# ^^^^ ^^^^ ^^^^
# BBBB CCCC AAAA
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 12
# num_matches_2 = 12
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0024509429931640625 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# Yun Ying Jin
# ^^^ ^^^^ ^^^
# BBB CCCC AAA
# Yunying Jin
# ^^^^^^^ ^^^
# BBBCCCC AAA
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 10
# num_matches_2 = 10
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.00042748451232910156 sec
# ##############################################################################################################################
# ---- [1/6] ---------------------------------------------------
# International I. Company Ltd
# ^^        ^   ^  ^^      ^^^
# AA        A   B  DD      CCC
# Int. Inn Co. Limited
# ^    ^^^ ^^  ^   ^ ^
# B    AAA DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [2/6] ---------------------------------------------------
# International I. Company Ltd
# ^    ^    ^   ^  ^^      ^^^
# A    A    A   B  DD      CCC
# Int. Inn Co. Limited
# ^    ^^^ ^^  ^   ^ ^
# B    AAA DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [3/6] ---------------------------------------------------
# International I. Company Ltd
# ^^   ^        ^  ^^      ^^^
# AA   A        B  DD      CCC
# Int. Inn Co. Limited
# ^    ^^^ ^^  ^   ^ ^
# B    AAA DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [4/6] ---------------------------------------------------
# International I. Company Ltd
# ^^^           ^  ^^      ^^^
# AAA           B  DD      CCC
# Int. Inn Co. Limited
# ^^^  ^   ^^  ^   ^ ^
# AAA  B   DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [5/6] ---------------------------------------------------
# International I. Company Ltd
# ^^     ^      ^  ^^      ^^^
# AA     A      B  DD      CCC
# Int. Inn Co. Limited
# ^^^  ^   ^^  ^   ^ ^
# AAA  B   DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [6/6] ---------------------------------------------------
# International I. Company Ltd
# ^    ^ ^      ^  ^^      ^^^
# A    A A      B  DD      CCC
# Int. Inn Co. Limited
# ^^^  ^   ^^  ^   ^ ^
# AAA  B   DD  C   C C
#
# score1 = 0.375, score2 = 0.6, avg(scores) = 0.4875
# num_matches_1 = 9
# num_matches_2 = 9
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0022063255310058594 sec
# ##############################################################################################################################
# ---- [1/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
#    ^  ^^   ^ ^^^
#    A  DD   B CCC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [2/12] ---------------------------------------------------
# International Inn Company Ltd
#         ^     ^   ^^      ^^^
#         A     B   DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# B  A  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [3/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
# ^  ^  ^^     ^^^
# B  A  DD     CCC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [4/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
# ^  ^  ^^   ^  ^^
# B  A  DD   C  CC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [5/12] ---------------------------------------------------
# International Inn Company Ltd
# ^             ^   ^^      ^^^
# A             B   DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# B  A  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [6/12] ---------------------------------------------------
# International Inn Company Ltd
# ^             ^   ^^      ^^^
# A             B   DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# A  B  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [7/12] ---------------------------------------------------
# International Inn Company Ltd
# ^       ^         ^^      ^^^
# A       B         DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# A  B  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [8/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
# ^     ^^   ^ ^^^
# A     DD   B CCC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [9/12] ---------------------------------------------------
# International Inn Company Ltd
#         ^     ^   ^^      ^^^
#         A     B   DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# A  B  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [10/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
# ^  ^  ^^     ^^^
# A  B  DD     CCC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [11/12] ---------------------------------------------------
# International Inn Company Ltd
# ^ ^^    ^     ^   ^^
# C CC    A     B   DD
# I. I. Co. Limited
# ^  ^  ^^   ^  ^^
# A  B  DD   C  CC
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [12/12] ---------------------------------------------------
# International Inn Company Ltd
# ^       ^         ^^      ^^^
# B       A         DD      CCC
# I. I. Co. Limited
# ^  ^  ^^  ^   ^ ^
# A  B  DD  C   C C
#
# score1 = 0.2692307692307692, score2 = 0.6363636363636364, avg(scores) = 0.4527972027972028
# num_matches_1 = 7
# num_matches_2 = 7
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
#
# TIME ELAPSED = 0.001997709274291992 sec
# ##############################################################################################################################
# ---- [1/3] ---------------------------------------------------
# Green Construction Corporation Ltd.
# ^^^^^ ^^^^^^^^^^^^ ^        ^  ^^^
# AAAAA BBBBBBBBBBBB C        C  DDD
# Green Construction Co., Limited
# ^^^^^ ^^^^^^^^^^^^ ^^   ^   ^ ^
# AAAAA BBBBBBBBBBBB CC   D   D D
#
# score1 = 0.7096774193548387, score2 = 0.8461538461538461, avg(scores) = 0.7779156327543424
# num_matches_1 = 22
# num_matches_2 = 22
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [2/3] ---------------------------------------------------
# Green Construction Corporation Ltd.
# ^^^^^ ^^^^^^^^^^^^ ^^          ^^^
# AAAAA BBBBBBBBBBBB CC          DDD
# Green Construction Co., Limited
# ^^^^^ ^^^^^^^^^^^^ ^^   ^   ^ ^
# AAAAA BBBBBBBBBBBB CC   D   D D
#
# score1 = 0.7096774193548387, score2 = 0.8461538461538461, avg(scores) = 0.7779156327543424
# num_matches_1 = 22
# num_matches_2 = 22
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [3/3] ---------------------------------------------------
# Green Construction Corporation Ltd.
# ^^^^^ ^^^^^^^^^^^^ ^   ^       ^^^
# AAAAA BBBBBBBBBBBB C   C       DDD
# Green Construction Co., Limited
# ^^^^^ ^^^^^^^^^^^^ ^^   ^   ^ ^
# AAAAA BBBBBBBBBBBB CC   D   D D
#
# score1 = 0.7096774193548387, score2 = 0.8461538461538461, avg(scores) = 0.7779156327543424
# num_matches_1 = 22
# num_matches_2 = 22
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.001983165740966797 sec
# ##############################################################################################################################
# ---- [1/6] ---------------------------------------------------
# United States of America
# ^      ^               ^
# A      B               C
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [2/6] ---------------------------------------------------
# United States of America
# ^      ^ ^
# A      B C
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [3/6] ---------------------------------------------------
# United States of America
# ^      ^         ^
# A      B         C
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [4/6] ---------------------------------------------------
# United States of America
# ^           ^          ^
# A           B          C
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [5/6] ---------------------------------------------------
# United States of America
# ^        ^  ^
# A        C  B
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [6/6] ---------------------------------------------------
# United States of America
# ^           ^    ^
# A           B    C
# U.S.A.
# ^ ^ ^
# A B C
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
#
# TIME ELAPSED = 0.0012996196746826172 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# United States of America
# ^      ^ ^
# A      B B
# USA
# ^^^
# ABB
#
# score1 = 0.14285714285714285, score2 = 1.0, avg(scores) = 0.5714285714285714
# num_matches_1 = 3
# num_matches_2 = 3
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0010151863098144531 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# New York, NY
# ^   ^     ^^
# B   C     AA
# NY, NY
# ^^  ^^
# AA  BC
#
# score1 = 0.4444444444444444, score2 = 1.0, avg(scores) = 0.7222222222222222
# num_matches_1 = 4
# num_matches_2 = 4
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# 1122 Hunter St.
# ^^^^ ^^^^^^ ^^
# CCDD AAAAAA BB
# 11 22 Hunter St.
# ^^ ^^ ^^^^^^ ^^
# CC DD AAAAAA BB
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 12
# num_matches_2 = 12
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0 sec
# ##############################################################################################################################
# ---- [1/1] ---------------------------------------------------
# 1122 Hunter St.
# ^^^^ ^^^^^^ ^^
# DDCC AAAAAA BB
# 22 11 Hunter St.
# ^^ ^^ ^^^^^^ ^^
# CC DD AAAAAA BB
#
# score1 = 1.0, score2 = 1.0, avg(scores) = 1.0
# num_matches_1 = 12
# num_matches_2 = 12
# RESULT: matched_full_or_none1 & matched_full_or_none2 = True
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0009958744049072266 sec
# ##############################################################################################################################
# ---- [1/2] ---------------------------------------------------
# 1122 Hunter St.
# ^^   ^^^^^^ ^^
# CC   AAAAAA BB
# 2211 Hunter St.
#   ^^ ^^^^^^ ^^
#   CC AAAAAA BB
#
# score1 = 0.8333333333333334, score2 = 0.8333333333333334, avg(scores) = 0.8333333333333334
# num_matches_1 = 10
# num_matches_2 = 10
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
# ---- [2/2] ---------------------------------------------------
# 1122 Hunter St.
#   ^^ ^^^^^^ ^^
#   CC AAAAAA BB
# 2211 Hunter St.
# ^^   ^^^^^^ ^^
# CC   AAAAAA BB
#
# score1 = 0.8333333333333334, score2 = 0.8333333333333334, avg(scores) = 0.8333333333333334
# num_matches_1 = 10
# num_matches_2 = 10
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = False
#
# TIME ELAPSED = 0.0010044574737548828 sec
# ##############################################################################################################################
# ---- [1/4] ---------------------------------------------------
# Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3
# ^^^^^ ^^^   ^^  ^^^^ ^^      ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG   HH  BBBB JJ      CCCC D  EEEEEEE  FFF II
# Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4
# ^^^^^ ^^^       ^ ^ ^^^^ ^^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG       H H BBBB JJ  CCCC D  EEEEEEE  FFF II
#
# score1 = 0.8461538461538461, score2 = 0.825, avg(scores) = 0.835576923076923
# num_matches_1 = 33
# num_matches_2 = 33
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [2/4] ---------------------------------------------------
# Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3
# ^^^^^ ^^^   ^^  ^^^^ ^    ^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG   HH  BBBB J    J  CCCC D  EEEEEEE  FFF II
# Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4
# ^^^^^ ^^^       ^ ^ ^^^^ ^^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG       H H BBBB JJ  CCCC D  EEEEEEE  FFF II
#
# score1 = 0.8461538461538461, score2 = 0.825, avg(scores) = 0.835576923076923
# num_matches_1 = 33
# num_matches_2 = 33
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [3/4] ---------------------------------------------------
# Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3
# ^^^^^ ^^^   ^ ^ ^^^^ ^^      ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG   H H BBBB JJ      CCCC D  EEEEEEE  FFF II
# Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4
# ^^^^^ ^^^       ^^  ^^^^ ^^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG       HH  BBBB JJ  CCCC D  EEEEEEE  FFF II
#
# score1 = 0.8461538461538461, score2 = 0.825, avg(scores) = 0.835576923076923
# num_matches_1 = 33
# num_matches_2 = 33
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
# ---- [4/4] ---------------------------------------------------
# Smith Bro., 123 Main Street, Unit 5, Scanton, A1B 2C3
# ^^^^^ ^^^   ^ ^ ^^^^ ^    ^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG   H H BBBB J    J  CCCC D  EEEEEEE  FFF II
# Smith Brothers, 132 Main St. Unit 5, Scanton, A1B 2C4
# ^^^^^ ^^^       ^^  ^^^^ ^^  ^^^^ ^  ^^^^^^^  ^^^ ^^
# AAAAA GGG       HH  BBBB JJ  CCCC D  EEEEEEE  FFF II
#
# score1 = 0.8461538461538461, score2 = 0.825, avg(scores) = 0.835576923076923
# num_matches_1 = 33
# num_matches_2 = 33
# RESULT: matched_full_or_none1 & matched_full_or_none2 = False
# RESULT: matched_full_or_purely_partial_from_initial1 & matched_full_or_purely_partial_from_initial2 = True
#
# TIME ELAPSED = 0.0025854110717773438 sec

# %% [markdown]
# # END
